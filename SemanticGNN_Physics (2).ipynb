# %% [markdown]
# # SemanticGNN-Physics: Complete Pipeline
#
# **Graph Neural Networks for Physics Equation Discovery**
#
# ## What This Notebook Does:
# 1. 🔬 Parse 400 physics equations (AST processing)
# 2. 🌐 Build knowledge graph (639 nodes, 4,557 bridges)
# 3. 🧠 Train SuperPhysicsGNN (52K parameters)
# 4. 📊 Analyze physics discoveries
#
# ## Expected Results:
# - **Quick version** (1000 epochs): AUC 0.9548 ± 0.0071
# - **Full version** (3000 epochs): AUC 0.9706 ± 0.0036
#
# ## Runtime:
# - Quick: ~15 minutes
# - Full: ~45 minutes
#
# **Ready? Click "Run All" to start! 🚀**

# %%
# ===============================================
# SEMANTICGNN-PHYSICS: COMPLETE PIPELINE
# ===============================================
print("🚀 SemanticGNN-Physics Pipeline Starting...")

# Install requirements
# !pip install torch-geometric

print("✅ Setup completed!")
# Out:
# 🚀 SemanticGNN-Physics Pipeline Starting...
# Collecting torch-geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.12.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2025.7.14)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.14.1)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.5 MB/s eta 0:00:00
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.6.1
# ✅ Setup completed!

# %%
# ===============================================
# STEP 1: AST PROCESSING
# ===============================================

# Run AST parser
# !python ast_parser.py
# Out:
# 🔬 AST ANALYZER - FINAL 100% VERSION WITH DEBUG
# ================================================================================
# ✅ Loaded 400 equations from final_physics_database.json
#
# 🧪 TESTING problematic equations...
#
# 📝 Testing: γ * m * c^2
#    After Greek: gamma * m * c^2
#    Final cleaned: gamma * m * c**2
#    Result: ✅ SUCCESS
#    Parsed as: c**2*gamma*m
#
# 📝 Testing: f_0 * sqrt((1 + β)/(1 - β))
#    After Greek: f_0 * sqrt((1 + beta)/(1 - beta))
#    Final cleaned: f_0 * sqrt((1 + beta)/(1 - beta))
#    Result: ✅ SUCCESS
#    Parsed as: f_0*sqrt((beta + 1)/(1 - beta))
#
# 📝 Testing: sqrt(γ * R * T / M)
#    After Greek: sqrt(gamma * R * T / M)
#    Final cleaned: sqrt(gamma * R * T / M)
#    Result: ✅ SUCCESS
#    Parsed as: sqrt(R*T*gamma/M)
#
# 📝 Testing: N_0 * exp(-λ * t)
#    After Greek: N_0 * exp(-lamda * t)
#    Final cleaned: N_0 * exp(-lamda * t)
#    Result: ✅ SUCCESS
#    Parsed as: N_0*exp(-lamda*t)
#
# 📝 Testing: I * ∫(dl × B)
#    After Greek: I * ∫(dl × B)
#    Final cleaned: I * Integral(dl * B, x)
#    Result: ✅ SUCCESS
#    Parsed as: I*Integral(B*dl, x)
#
# 📝 Testing: ∫(dQ / T)
#    After Greek: ∫(dQ / T)
#    Final cleaned: Integral(dQ / T, x)
#    Result: ✅ SUCCESS
#    Parsed as: Integral(dQ/T, x)
#
# ================================================================================
# 🔬 Running COMPLETE analysis on ALL equations...
# 🚀 STARTING COMPREHENSIVE STRUCTURAL ANALYSIS...
# 📊 Total equations to analyze: 400
#
# 📈 Progress: 10.0% (40/400 equations processed)
#    ✅ Successful: 40 (97.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 20.0% (80/400 equations processed)
#    ✅ Successful: 80 (98.8%)
#    ❌ Failed: 0
#
# 📈 Progress: 30.0% (120/400 equations processed)
#    ✅ Successful: 120 (99.2%)
#    ❌ Failed: 0
#
# 📈 Progress: 40.0% (160/400 equations processed)
#    ✅ Successful: 160 (99.4%)
#    ❌ Failed: 0
#
# 📈 Progress: 50.0% (200/400 equations processed)
#    ✅ Successful: 200 (99.5%)
#    ❌ Failed: 0
#
# 📈 Progress: 60.0% (240/400 equations processed)
#    ✅ Successful: 240 (99.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 70.0% (280/400 equations processed)
#    ✅ Successful: 280 (99.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 80.0% (320/400 equations processed)
#    ✅ Successful: 320 (99.7%)
#    ❌ Failed: 0
#
# 📈 Progress: 90.0% (360/400 equations processed)
#    ✅ Successful: 360 (99.7%)
#    ❌ Failed: 0
#
# ✅ Analysis completed!
#    📊 Total equations: 400
#    ✅ Successful parses: 400 (100.0%)
#    ❌ Failed parses: 0 (0.0%)
#
# 💾 Results saved to: ast_analysis_results_20250807_110324.json
# 📊 Creating visualizations...
# 📊 Visualizations saved to: ast_analysis_plots/
# 📄 Text report saved to: ast_analysis_report_20250807_110324.txt
#
# ================================================================================
# 🎉 ANALYSIS COMPLETE!
# ================================================================================
#
# 🏆 Most Complex Equation:
#    ID: adv_0160
#    Equation: 4*π * (m/(2*π*k*T))^(3/2) * v² * exp(-m*v²/(2*k*T))
#    Total Nodes: 34
#    Max Depth: 4
#
# 🏔️ Deepest Equation:
#    ID: adv_0030
#    Equation: sqrt(R^2 + (ω*L - 1/(ω*C))^2)
#    Max Depth: 6

# %%
# ===============================================
# STEP 2: GRAPH CONSTRUCTION
# ===============================================

# Run graph builder
# !python graph_builder.py
# Out:
# ============================================================
# GRAPH3EV - PHYSICS KNOWLEDGE GRAPH BUILDER v3.1
# (Post Peer-Review Edition with Literature-Based Weights)
# ============================================================
#
# 📚 Loading equations from final_physics_database.json...
#   Found equations under 'laws' key
#   Database version: 3.0
#   Total laws in DB: 400
# ✓ Loaded 400 equations
#
# 🔍 Optimizing hyperparameters with grid search...
# ✓ Optimal hyperparameters: α=0.100, β=0.100, γ=0.800
#
# 🔨 Building base graph structure...
# Processing equations: 100% 400/400 [00:00<00:00, 113420.88it/s]
# ✓ Created 400 equation nodes
# ✓ Created 239 concept nodes
# ✓ Created 2692 concept-equation edges
#
# 🌉 Creating equation bridges with normalized weights...
# Finding equation bridges: 100% 399/399 [00:00<00:00, 2686.72it/s]
# ✓ Found 10422 equation bridges
#   - Same-branch: 2746
#   - Cross-branch: 7676
# ✓ Kept 4557 significant bridges
#   Same-branch threshold: 0.898 (top 25%)
#   Cross-branch threshold: 0.461 (top 50%)
#
# ============================================================
# GRAPH CONSTRUCTION SUMMARY
# ============================================================
# Total nodes: 639
#   - Equation nodes: 400
#   - Concept nodes: 239
#
# Total edges: 11,806
#   - Concept-equation edges: 2,692
#   - Equation bridge edges: 9,114
#
# Graph density: 0.0290
#
# 📊 BRIDGE STATISTICS:
# Total bridges found: 10,422
# Significant bridges: 4,557
# Average normalized weight: 0.690
# Cross-branch bridges: 3,838
# High quality bridges: 2,372
#
# 🔧 Hyperparameters used:
#   α (Jaccard weight): 0.100
#   β (Physics weight): 0.100
#   γ (Branch weight): 0.800
#
# 🌟 TOP EQUATION HUBS:
# 1. Compton Scattering - Wavelength Shift (Quantum Mechanics)
#    Connections: 92, Avg weight: 0.704
# 2. Group Velocity (Optics)
#    Connections: 85, Avg weight: 0.706
# 3. Hydrogen Energy Levels - Bohr Model (Ryh) (Atomic and Nuclear Physics)
#    Connections: 85, Avg weight: 0.646
# 4. Harmonic Oscillator - Quantum (sqr) (Quantum Mechanics)
#    Connections: 85, Avg weight: 0.646
# 5. Phase Velocity (Optics)
#    Connections: 79, Avg weight: 0.714
#
# 🌉 EXAMPLE HIGH-WEIGHT BRIDGES:
#
# 1. Fermi-Dirac Distribution - Fermions <---> Bose-Einstein Distribution - Bosons
#       Weight: 0.968
#       Shared concepts: T, e, k, μ
#       Quality score: 0.802
#       Cross-branch: No
#
# 2. Dipole Field (Axial) <---> Dipole Field (Equatorial)
#       Weight: 0.965
#       Shared concepts: e, p, r3
#       Quality score: 0.762
#       Cross-branch: No
#
# 3. Relativistic Energy - Special Relativity (sqr) <---> Four-Momentum - Relativistic Invariant (pμp)
#       Weight: 0.961
#       Shared concepts: c, m, p
#       Quality score: 0.958
#       Cross-branch: No
#
# 💾 Graph saved to: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
# 📋 Metadata saved to: knowledge_graph_outputs/graph_metadata_20250807_110335.json
# 🌉 Bridge analysis saved to: knowledge_graph_outputs/equation_bridges_20250807_110335.json
#
# ✅ GRAPH BUILDING COMPLETE!
#    The knowledge graph now includes 4557 significant equation bridges
#    with properly normalized weights based on:
#    • Physics importance scores from Zeng et al. (2017) & Chen-Börner (2016)
#    • Branch similarity matrix from Börner et al. (2005) & updates
#    • Data-driven hyperparameter optimization
#    • Adaptive thresholds to preserve interdisciplinary connections
#
#    Ready for publication-quality GNN analysis!
#
# ============================================================
# EXAMPLE: Accessing Bridge Information
# ============================================================
#
# Edge attributes shape: torch.Size([11806, 3])
# Each edge has 3 attributes: [normalized_weight, fundamental_weight, quality_score]
#
# High quality edges (score > 0.7): 7436
# Average normalized weight: 0.761
#
# ✨ Ready for advanced GNN analysis with properly normalized equation bridges!

# %%
# ===============================================
# STEP 3: SUPERGNN TRAINING & EVALUATION
# ===============================================

# Run SuperGNN training 5 seeds, 1000 epochs
# !python gnn_trainer_1000.py

print("For 3000 epoch training replace above with: !python gnntrainer_3000.py")
# Out:
# ================================================================================
# SUPER GNN PRO - ULTIMATE PHYSICS KNOWLEDGE DISCOVERY
# ================================================================================
#
# 🎲 RUN #1/5 - SEED: 42
# ============================================================
# 🎲 RUN - SEED: 42
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 11:03:43,328 - INFO - Model on device: cuda
# 2025-08-07 11:03:43,328 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 11:03:43,330 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 11:03:43,331 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:05<00:00, 15.31it/s, loss=0.8105, auc=0.9524, ap=0.9418, best_auc=0.9598, lr=0.000854]
# 2025-08-07 11:04:48,667 - INFO - Training completed. Best validation AUC: 0.9598
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9590 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9519
#    - acc: 0.8891
#    - pos_acc: 0.9195
#    - neg_acc: 0.8587
#    - p@r0.1: 0.9832
#    - p@r0.3: 0.9832
#    - p@r0.5: 0.9750
#    - p@r0.7: 0.9490
#    - p@r0.9: 0.8863
#
# 🔮 Generating advanced predictions...
# 2025-08-07 11:04:48,683 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 11:04:48,688 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4818.12it/s]
# 2025-08-07 11:05:04,648 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 11:05:08,249 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 42)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9590
#    - Test AP: 0.9519
#    - Precision@Recall=0.9: 0.8863
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_110504_seed42.txt
#
# 🎲 RUN #2/5 - SEED: 123
# ============================================================
# 🎲 RUN - SEED: 123
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 11:05:08,285 - INFO - Model on device: cuda
# 2025-08-07 11:05:08,285 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 11:05:08,287 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 11:05:08,287 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:03<00:00, 15.78it/s, loss=0.7969, auc=0.9589, ap=0.9538, best_auc=0.9646, lr=0.000854]
# 2025-08-07 11:06:11,660 - INFO - Training completed. Best validation AUC: 0.9646
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9597 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9544
#    - acc: 0.8938
#    - pos_acc: 0.9092
#    - neg_acc: 0.8784
#    - p@r0.1: 0.9915
#    - p@r0.3: 0.9887
#    - p@r0.5: 0.9782
#    - p@r0.7: 0.9424
#    - p@r0.9: 0.8930
#
# 🔮 Generating advanced predictions...
# 2025-08-07 11:06:11,676 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 11:06:11,681 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4820.14it/s]
# 2025-08-07 11:06:27,634 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 11:06:31,264 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 123)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9597
#    - Test AP: 0.9544
#    - Precision@Recall=0.9: 0.8930
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_110628_seed123.txt
#
# 🎲 RUN #3/5 - SEED: 456
# ============================================================
# 🎲 RUN - SEED: 456
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 11:06:31,302 - INFO - Model on device: cuda
# 2025-08-07 11:06:31,302 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 11:06:31,304 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 11:06:31,304 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:03<00:00, 15.65it/s, loss=0.7927, auc=0.9639, ap=0.9601, best_auc=0.9649, lr=0.000854]
# 2025-08-07 11:07:35,204 - INFO - Training completed. Best validation AUC: 0.9649
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9685 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9651
#    - acc: 0.9122
#    - pos_acc: 0.9538
#    - neg_acc: 0.8707
#    - p@r0.1: 1.0000
#    - p@r0.3: 0.9943
#    - p@r0.5: 0.9882
#    - p@r0.7: 0.9512
#    - p@r0.9: 0.9108
#
# 🔮 Generating advanced predictions...
# 2025-08-07 11:07:35,221 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 11:07:35,227 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4853.74it/s]
# 2025-08-07 11:07:51,079 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 11:07:54,635 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 456)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9685
#    - Test AP: 0.9651
#    - Precision@Recall=0.9: 0.9108
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_110751_seed456.txt
#
# 🎲 RUN #4/5 - SEED: 789
# ============================================================
# 🎲 RUN - SEED: 789
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 11:07:54,670 - INFO - Model on device: cuda
# 2025-08-07 11:07:54,671 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 11:07:54,673 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 11:07:54,673 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:03<00:00, 15.73it/s, loss=0.7806, auc=0.9619, ap=0.9553, best_auc=0.9658, lr=0.000854]
# 2025-08-07 11:08:58,245 - INFO - Training completed. Best validation AUC: 0.9658
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9646 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9607
#    - acc: 0.9041
#    - pos_acc: 0.9358
#    - neg_acc: 0.8724
#    - p@r0.1: 0.9915
#    - p@r0.3: 0.9860
#    - p@r0.5: 0.9782
#    - p@r0.7: 0.9635
#    - p@r0.9: 0.8991
#
# 🔮 Generating advanced predictions...
# 2025-08-07 11:08:58,261 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 11:08:58,266 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4898.56it/s]
# 2025-08-07 11:09:13,972 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 11:09:17,555 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 789)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9646
#    - Test AP: 0.9607
#    - Precision@Recall=0.9: 0.8991
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_110914_seed789.txt
#
# 🎲 RUN #5/5 - SEED: 999
# ============================================================
# 🎲 RUN - SEED: 999
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 11:09:17,592 - INFO - Model on device: cuda
# 2025-08-07 11:09:17,592 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 11:09:17,594 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 11:09:17,594 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:03<00:00, 15.63it/s, loss=0.8132, auc=0.9494, ap=0.9387, best_auc=0.9573, lr=0.000854]
# 2025-08-07 11:10:21,559 - INFO - Training completed. Best validation AUC: 0.9573
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9487 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9435
#    - acc: 0.8848
#    - pos_acc: 0.9212
#    - neg_acc: 0.8485
#    - p@r0.1: 1.0000
#    - p@r0.3: 0.9804
#    - p@r0.5: 0.9621
#    - p@r0.7: 0.9317
#    - p@r0.9: 0.8701
#
# 🔮 Generating advanced predictions...
# 2025-08-07 11:10:21,575 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 11:10:21,580 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4762.62it/s]
# 2025-08-07 11:10:37,721 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 11:10:41,332 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 999)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9487
#    - Test AP: 0.9435
#    - Precision@Recall=0.9: 0.8701
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_111037_seed999.txt
#
# ================================================================================
# 🎉 ALL 5 DETERMINISTIC RUNS COMPLETED!
# ================================================================================
#
# 📊 AGGREGATE METRICS ACROSS SEEDS:
#    - AUC: 0.9601 ± 0.0067 (seeds: [42, 123, 456, 789, 999])
#    - AP:  0.9551 ± 0.0074 (seeds: [42, 123, 456, 789, 999])
#
# 🚀 The Super GNN has revealed the hidden structure of physics!
# For 3000 epoch training replace above with: !python gnntrainer_3000.py

# %%
# !python compa5.py
# Out:
# ================================================================================
# SUPER GNN v2 - STATISTICAL VALIDATION WITH FAIR COMPARISON
# ================================================================================
#
# 🖥️  Device: cuda
# 🔍 Current directory: /content
# 🔍 Checking in: /content/knowledge_graph_outputs
# ✅ Found 1 files in knowledge_graph_outputs
# 📊 Total graph files found: 1
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_110335.pt
# 📋 Looking for metadata: knowledge_graph_outputs/graph_metadata_20250807_110335.json
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# ================================================================================
# 🔬 COMPLETE MODEL EVALUATION AND STATISTICAL VALIDATION
# ================================================================================
#
# 📊 Evaluating Classical Baselines...
#    - common_neighbors... AUC: 0.9487, AP: 0.9491
#    - jaccard... AUC: 0.9453, AP: 0.9416
#    - adamic_adar... AUC: 0.9481, AP: 0.9480
#    - preferential_attachment... AUC: 0.8728, AP: 0.8798
#
# 🧠 Training Neural Models (5 runs each for statistical significance)...
#    ALL models use: 64→32→16 architecture, 5000 epochs, patience=500
#
#    SUPER GNN (Full Features, 64→32→16):
#       Run 1/5... Test AUC: 0.9761
#       Run 2/5... Test AUC: 0.9766
#       Run 3/5... Test AUC: 0.9721
#       Run 4/5... Test AUC: 0.9732
#       Run 5/5... Test AUC: 0.9732
#
#    GAT Simplified (Basic, 64→32→16):
#       Run 1/5... Test AUC: 0.9151
#       Run 2/5... Test AUC: 0.9575
#       Run 3/5... Test AUC: 0.9195
#       Run 4/5... Test AUC: 0.9254
#       Run 5/5... Test AUC: 0.9446
#
#    GCN:
#       Run 1/5... Test AUC: 0.9430
#       Run 2/5... Test AUC: 0.9197
#       Run 3/5... Test AUC: 0.9439
#       Run 4/5... Test AUC: 0.9407
#       Run 5/5... Test AUC: 0.9349
#
#    GraphSAGE:
#       Run 1/5... Test AUC: 0.9288
#       Run 2/5... Test AUC: 0.9427
#       Run 3/5... Test AUC: 0.9580
#       Run 4/5... Test AUC: 0.9624
#       Run 5/5... Test AUC: 0.9599
#
# 🔧 Ablation Study on GAT:
#    - GAT without edge weights... Mean AUC: 0.9306
#    - GAT with single attention head... Mean AUC: 0.8973
#
# 📈 Statistical Significance Tests:
#
#    SUPER GNN vs GAT Simplified:
#       Mean difference: 0.0418
#       p-value: 5.7762e-03
#       Significant: YES
#
#    SUPER GNN vs common_neighbors:
#       Mean difference: 0.0255
#       p-value: 9.0038e-06
#       Significant: YES
#
#    SUPER GNN vs GCN:
#       Mean difference: 0.0378
#       p-value: 1.7016e-03
#       Significant: YES
#
#    SUPER GNN vs GraphSAGE:
#       Mean difference: 0.0239
#       p-value: 2.9035e-02
#       Significant: YES
#
# 📊 Creating validation plots...
#
# 📄 Validation report saved to: validation_results/validation_report_20250807_115500.txt
#
# ================================================================================
# ✅ STATISTICAL VALIDATION COMPLETE!
# ================================================================================
#
# 🏆 FINAL RESULTS:
#    Best Baseline: common_neighbors (AUC: 0.9487)
#    SUPER GNN (Full Features): AUC = 0.9742 ± 0.0018
#    GAT Simplified (Basic):    AUC = 0.9324 ± 0.0161
#
#    SUPER GNN improvement over baseline: 2.7%
#    Simplified GAT improvement over baseline: -1.7%
#
# 📁 All results saved to: validation_results/
#
# 🔬 Fair comparison with IDENTICAL architectures (64→32→16) and training params!
#    The SUPER GNN's superior performance comes from advanced features,
#    NOT from having more parameters!

# %%
# !python fdr3-it.py
# Out:
# ================================================================================
# RIGOROUS FDR ANALYSIS - STRATIFIED SAMPLE
# ================================================================================
#
# 📊 SAMPLING CONTEXT:
#    Nodes in graph: 639
#    Possible edges: 203,841
#    Samples analyzed: 5000
#
# 🔬 NEGATIVE CONTROLS GENERATION
# ------------------------------------------------------------
# ✅ Generated 600 negative controls
#    Mean: 0.346
#    Median: 0.310
#    Max: 0.800
#    [0.0-0.6]: 524 controls (87.3%)
#    [0.6-0.7]: 44 controls (7.3%)
#    [0.7-0.8]: 32 controls (5.3%)
#
# 🎯 INTERMEDIATE ZONE ANALYSIS (0.6-0.85)
# ------------------------------------------------------------
# Samples in intermediate zone: 2395 (47.9%)
#    Estimated noise proportion: 0.140
#    Estimated signal proportion: 0.860
#
# 📈 FDR CALCULATION WITH BOOTSTRAPPING
# ------------------------------------------------------------
# Soglia | FDR Mean | 95% CI         | Samples Above
# -------------------------------------------------------
# 0.50   | 0.314    | [0.264, 0.355] | 4054
# 0.55   | 0.235    | [0.199, 0.279] | 4024
# 0.60   | 0.158    | [0.124, 0.192] | 4000
# 0.65   | 0.126    | [0.095, 0.157] | 3496
# 0.70   | 0.089    | [0.061, 0.125] | 3000
# 0.75   | 0.043    | [0.022, 0.066] | 2557
# 0.80   | 0.000    | [0.000, 0.000] | 2000
# 0.85   | 0.000    | [0.000, 0.000] | 1605
# 0.90   | 0.000    | [0.000, 0.000] | 1000
# 0.95   | 0.000    | [0.000, 0.000] | 9
#
# 🔍 SENSITIVITY ANALYSIS ON NOISE/SIGNAL THRESHOLD DEFINITIONS
# ------------------------------------------------------------
#
# FDR Matrix (at threshold 0.9) varying definitions:
# Signal →
# Noise ↓   0.85  0.90  0.92  0.94  0.95  0.98
# 0.1      0.000  0.000  0.000  0.000    -      -
# 0.2      0.000  0.000  0.000  0.000    -      -
# 0.3      0.000  0.000  0.000  0.000    -      -
# 0.4      0.000  0.000  0.000  0.000    -      -
# 0.5      0.000  0.000  0.000  0.000    -      -
# 0.6      0.000  0.000  0.000  0.000    -      -
# Figure(2000x1600)
#
# ================================================================================
# 📊 FINAL FDR ANALYSIS REPORT
# ================================================================================
#
# ✅ OPTIMAL THRESHOLD for FDR ≤ 5%:
#    Threshold: 0.750
#    Estimated FDR: 0.043 (95% CI: [0.022, 0.066])
#    Predictions above threshold: 2557
#
# 🔬 ADVANCED QUALITY ASSESSMENT:
#
# QUALITY SCORE: 4/5
#    ✓ Strong separation predictions/negatives (KS p=9.42e-237)
#    ✓ Intermediate zone well populated (2395 samples)
#    ✓ Stable FDR estimates (std=0.000 at threshold 0.9)
#
# ✅ Analysis saved to: /content/fdr_analysis_results/
#
# 📌 CONCLUSIONS:
#    1. FDR estimated with robust methods (bootstrap + negative controls)
#    2. Critical intermediate zone identified for validation
#    3. Sensitivity analysis shows stability of estimates
#    4. Complete report with confidence intervals and recommendations

# %%
# ===============================================
# STATISTICAL ANALISYS
# ===============================================

# Run fdr
# !python fdr_analysis.py

# %%
# ===============================================
# STATISTICAL ANALISYS
# ===============================================

# Run models comparison
# !python models_comparison.py

# %%
# ===============================================
# Extra visualizations
# ===============================================

# Run ego networks
# !python ego_networks.py
