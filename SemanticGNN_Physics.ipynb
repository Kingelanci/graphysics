# %% [markdown]
# # SemanticGNN-Physics: Complete Pipeline
#
# **Graph Neural Networks for Physics Equation Discovery**
#
# ## What This Notebook Does:
# 1. 🔬 Parse 400 physics equations (AST processing)
# 2. 🌐 Build knowledge graph (639 nodes, 4,557 bridges)
# 3. 🧠 Train SuperPhysicsGNN (52K parameters)
# 4. 📊 Analyze physics discoveries
#
# ## Expected Results:
# - **Quick version** (1000 epochs): AUC 0.9548 ± 0.0071
# - **Full version** (3000 epochs): AUC 0.9706 ± 0.0036
#
# ## Runtime:
# - Quick: ~15 minutes
# - Full: ~45 minutes
#
# **Ready? Click "Run All" to start! 🚀**

# %%
# ===============================================
# SEMANTICGNN-PHYSICS: COMPLETE PIPELINE
# ===============================================
print("🚀 SemanticGNN-Physics Pipeline Starting...")

# Install requirements
# !pip install torch-geometric

print("✅ Setup completed!")
# Out:
# 🚀 SemanticGNN-Physics Pipeline Starting...
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.12.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch-geometric) (1.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch-geometric) (2025.7.14)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch-geometric) (4.14.1)
# ✅ Setup completed!

# %%
# ===============================================
# STEP 1: AST PROCESSING
# ===============================================

# Run AST parser
# !python ast_parser.py
# Out:
# 🔬 AST ANALYZER - FINAL 100% VERSION WITH DEBUG
# ================================================================================
# ✅ Loaded 400 equations from final_physics_database.json
#
# 🧪 TESTING problematic equations...
#
# 📝 Testing: γ * m * c^2
#    After Greek: gamma * m * c^2
#    Final cleaned: gamma * m * c**2
#    Result: ✅ SUCCESS
#    Parsed as: c**2*gamma*m
#
# 📝 Testing: f_0 * sqrt((1 + β)/(1 - β))
#    After Greek: f_0 * sqrt((1 + beta)/(1 - beta))
#    Final cleaned: f_0 * sqrt((1 + beta)/(1 - beta))
#    Result: ✅ SUCCESS
#    Parsed as: f_0*sqrt((beta + 1)/(1 - beta))
#
# 📝 Testing: sqrt(γ * R * T / M)
#    After Greek: sqrt(gamma * R * T / M)
#    Final cleaned: sqrt(gamma * R * T / M)
#    Result: ✅ SUCCESS
#    Parsed as: sqrt(R*T*gamma/M)
#
# 📝 Testing: N_0 * exp(-λ * t)
#    After Greek: N_0 * exp(-lamda * t)
#    Final cleaned: N_0 * exp(-lamda * t)
#    Result: ✅ SUCCESS
#    Parsed as: N_0*exp(-lamda*t)
#
# 📝 Testing: I * ∫(dl × B)
#    After Greek: I * ∫(dl × B)
#    Final cleaned: I * Integral(dl * B, x)
#    Result: ✅ SUCCESS
#    Parsed as: I*Integral(B*dl, x)
#
# 📝 Testing: ∫(dQ / T)
#    After Greek: ∫(dQ / T)
#    Final cleaned: Integral(dQ / T, x)
#    Result: ✅ SUCCESS
#    Parsed as: Integral(dQ/T, x)
#
# ================================================================================
# 🔬 Running COMPLETE analysis on ALL equations...
# 🚀 STARTING COMPREHENSIVE STRUCTURAL ANALYSIS...
# 📊 Total equations to analyze: 400
#
# 📈 Progress: 10.0% (40/400 equations processed)
#    ✅ Successful: 40 (97.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 20.0% (80/400 equations processed)
#    ✅ Successful: 80 (98.8%)
#    ❌ Failed: 0
#
# 📈 Progress: 30.0% (120/400 equations processed)
#    ✅ Successful: 120 (99.2%)
#    ❌ Failed: 0
#
# 📈 Progress: 40.0% (160/400 equations processed)
#    ✅ Successful: 160 (99.4%)
#    ❌ Failed: 0
#
# 📈 Progress: 50.0% (200/400 equations processed)
#    ✅ Successful: 200 (99.5%)
#    ❌ Failed: 0
#
# 📈 Progress: 60.0% (240/400 equations processed)
#    ✅ Successful: 240 (99.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 70.0% (280/400 equations processed)
#    ✅ Successful: 280 (99.6%)
#    ❌ Failed: 0
#
# 📈 Progress: 80.0% (320/400 equations processed)
#    ✅ Successful: 320 (99.7%)
#    ❌ Failed: 0
#
# 📈 Progress: 90.0% (360/400 equations processed)
#    ✅ Successful: 360 (99.7%)
#    ❌ Failed: 0
#
# ✅ Analysis completed!
#    📊 Total equations: 400
#    ✅ Successful parses: 400 (100.0%)
#    ❌ Failed parses: 0 (0.0%)
#
# 💾 Results saved to: ast_analysis_results_20250807_101442.json
# 📊 Creating visualizations...
# 📊 Visualizations saved to: ast_analysis_plots/
# 📄 Text report saved to: ast_analysis_report_20250807_101442.txt
#
# ================================================================================
# 🎉 ANALYSIS COMPLETE!
# ================================================================================
#
# 🏆 Most Complex Equation:
#    ID: adv_0160
#    Equation: 4*π * (m/(2*π*k*T))^(3/2) * v² * exp(-m*v²/(2*k*T))
#    Total Nodes: 34
#    Max Depth: 4
#
# 🏔️ Deepest Equation:
#    ID: adv_0030
#    Equation: sqrt(R^2 + (ω*L - 1/(ω*C))^2)
#    Max Depth: 6

# %%
# ===============================================
# STEP 2: GRAPH CONSTRUCTION
# ===============================================

# Run graph builder
# !python graph_builder.py
# Out:
# ============================================================
# GRAPH3EV - PHYSICS KNOWLEDGE GRAPH BUILDER v3.1
# (Post Peer-Review Edition with Literature-Based Weights)
# ============================================================
#
# 📚 Loading equations from final_physics_database.json...
#   Found equations under 'laws' key
#   Database version: 3.0
#   Total laws in DB: 400
# ✓ Loaded 400 equations
#
# 🔍 Optimizing hyperparameters with grid search...
# ✓ Optimal hyperparameters: α=0.100, β=0.100, γ=0.800
#
# 🔨 Building base graph structure...
# Processing equations: 100% 400/400 [00:00<00:00, 89813.79it/s]
# ✓ Created 400 equation nodes
# ✓ Created 239 concept nodes
# ✓ Created 2692 concept-equation edges
#
# 🌉 Creating equation bridges with normalized weights...
# Finding equation bridges: 100% 399/399 [00:00<00:00, 2945.72it/s]
# ✓ Found 10422 equation bridges
#   - Same-branch: 2746
#   - Cross-branch: 7676
# ✓ Kept 4557 significant bridges
#   Same-branch threshold: 0.898 (top 25%)
#   Cross-branch threshold: 0.461 (top 50%)
#
# ============================================================
# GRAPH CONSTRUCTION SUMMARY
# ============================================================
# Total nodes: 639
#   - Equation nodes: 400
#   - Concept nodes: 239
#
# Total edges: 11,806
#   - Concept-equation edges: 2,692
#   - Equation bridge edges: 9,114
#
# Graph density: 0.0290
#
# 📊 BRIDGE STATISTICS:
# Total bridges found: 10,422
# Significant bridges: 4,557
# Average normalized weight: 0.690
# Cross-branch bridges: 3,838
# High quality bridges: 2,372
#
# 🔧 Hyperparameters used:
#   α (Jaccard weight): 0.100
#   β (Physics weight): 0.100
#   γ (Branch weight): 0.800
#
# 🌟 TOP EQUATION HUBS:
# 1. Compton Scattering - Wavelength Shift (Quantum Mechanics)
#    Connections: 92, Avg weight: 0.704
# 2. Group Velocity (Optics)
#    Connections: 85, Avg weight: 0.706
# 3. Hydrogen Energy Levels - Bohr Model (Ryh) (Atomic and Nuclear Physics)
#    Connections: 85, Avg weight: 0.646
# 4. Harmonic Oscillator - Quantum (sqr) (Quantum Mechanics)
#    Connections: 85, Avg weight: 0.646
# 5. Phase Velocity (Optics)
#    Connections: 79, Avg weight: 0.714
#
# 🌉 EXAMPLE HIGH-WEIGHT BRIDGES:
#
# 1. Fermi-Dirac Distribution - Fermions <---> Bose-Einstein Distribution - Bosons
#       Weight: 0.968
#       Shared concepts: T, e, k, μ
#       Quality score: 0.802
#       Cross-branch: No
#
# 2. Dipole Field (Axial) <---> Dipole Field (Equatorial)
#       Weight: 0.965
#       Shared concepts: e, p, r3
#       Quality score: 0.762
#       Cross-branch: No
#
# 3. Relativistic Energy - Special Relativity (sqr) <---> Four-Momentum - Relativistic Invariant (pμp)
#       Weight: 0.961
#       Shared concepts: c, m, p
#       Quality score: 0.958
#       Cross-branch: No
#
# 💾 Graph saved to: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
# 📋 Metadata saved to: knowledge_graph_outputs/graph_metadata_20250807_101448.json
# 🌉 Bridge analysis saved to: knowledge_graph_outputs/equation_bridges_20250807_101448.json
#
# ✅ GRAPH BUILDING COMPLETE!
#    The knowledge graph now includes 4557 significant equation bridges
#    with properly normalized weights based on:
#    • Physics importance scores from Zeng et al. (2017) & Chen-Börner (2016)
#    • Branch similarity matrix from Börner et al. (2005) & updates
#    • Data-driven hyperparameter optimization
#    • Adaptive thresholds to preserve interdisciplinary connections
#
#    Ready for publication-quality GNN analysis!
#
# ============================================================
# EXAMPLE: Accessing Bridge Information
# ============================================================
#
# Edge attributes shape: torch.Size([11806, 3])
# Each edge has 3 attributes: [normalized_weight, fundamental_weight, quality_score]
#
# High quality edges (score > 0.7): 7436
# Average normalized weight: 0.761
#
# ✨ Ready for advanced GNN analysis with properly normalized equation bridges!

# %%
# ===============================================
# STEP 3: SUPERGNN TRAINING & EVALUATION
# ===============================================

# Run SuperGNN training 5 seeds, 1000 epochs
# !python gnn_trainer_1000.py

print("For 3000 epoch training replace above with: !python gnntrainer_3000.py")
# Out:
# ================================================================================
# SUPER GNN PRO - ULTIMATE PHYSICS KNOWLEDGE DISCOVERY
# ================================================================================
#
# 🎲 RUN #1/5 - SEED: 42
# ============================================================
# 🎲 RUN - SEED: 42
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 10:14:54,987 - INFO - Model on device: cuda
# 2025-08-07 10:14:54,987 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 10:14:54,990 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 10:14:54,990 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:05<00:00, 15.20it/s, loss=0.8138, auc=0.9541, ap=0.9470, best_auc=0.9541, lr=0.000854]
# 2025-08-07 10:16:00,784 - INFO - Training completed. Best validation AUC: 0.9541
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9444 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9384
#    - acc: 0.8729
#    - pos_acc: 0.8964
#    - neg_acc: 0.8493
#    - p@r0.1: 1.0000
#    - p@r0.3: 0.9860
#    - p@r0.5: 0.9558
#    - p@r0.7: 0.9201
#    - p@r0.9: 0.8511
#
# 🔮 Generating advanced predictions...
# 2025-08-07 10:16:00,800 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 10:16:00,805 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4816.05it/s]
# 2025-08-07 10:16:16,770 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 10:16:20,422 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 42)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9444
#    - Test AP: 0.9384
#    - Precision@Recall=0.9: 0.8511
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_101617_seed42.txt
#
# 🎲 RUN #2/5 - SEED: 123
# ============================================================
# 🎲 RUN - SEED: 123
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 10:16:20,456 - INFO - Model on device: cuda
# 2025-08-07 10:16:20,456 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 10:16:20,458 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 10:16:20,458 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:05<00:00, 15.16it/s, loss=0.8058, auc=0.9603, ap=0.9509, best_auc=0.9635, lr=0.000854]
# 2025-08-07 10:17:26,411 - INFO - Training completed. Best validation AUC: 0.9635
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9511 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9415
#    - acc: 0.8883
#    - pos_acc: 0.9152
#    - neg_acc: 0.8613
#    - p@r0.1: 0.9832
#    - p@r0.3: 0.9777
#    - p@r0.5: 0.9589
#    - p@r0.7: 0.9402
#    - p@r0.9: 0.8745
#
# 🔮 Generating advanced predictions...
# 2025-08-07 10:17:26,429 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 10:17:26,435 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4805.43it/s]
# 2025-08-07 10:17:42,438 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 10:17:46,104 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 123)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9511
#    - Test AP: 0.9415
#    - Precision@Recall=0.9: 0.8745
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_101742_seed123.txt
#
# 🎲 RUN #3/5 - SEED: 456
# ============================================================
# 🎲 RUN - SEED: 456
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 10:17:46,141 - INFO - Model on device: cuda
# 2025-08-07 10:17:46,141 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 10:17:46,143 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 10:17:46,143 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:06<00:00, 15.03it/s, loss=0.7786, auc=0.9598, ap=0.9535, best_auc=0.9671, lr=0.000854]
# 2025-08-07 10:18:52,660 - INFO - Training completed. Best validation AUC: 0.9671
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9662 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9597
#    - acc: 0.9041
#    - pos_acc: 0.9478
#    - neg_acc: 0.8604
#    - p@r0.1: 0.9832
#    - p@r0.3: 0.9915
#    - p@r0.5: 0.9750
#    - p@r0.7: 0.9523
#    - p@r0.9: 0.9116
#
# 🔮 Generating advanced predictions...
# 2025-08-07 10:18:52,676 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 10:18:52,681 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4753.08it/s]
# 2025-08-07 10:19:08,858 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 10:19:12,467 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 456)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9662
#    - Test AP: 0.9597
#    - Precision@Recall=0.9: 0.9116
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_101909_seed456.txt
#
# 🎲 RUN #4/5 - SEED: 789
# ============================================================
# 🎲 RUN - SEED: 789
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 10:19:12,504 - INFO - Model on device: cuda
# 2025-08-07 10:19:12,504 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 10:19:12,506 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 10:19:12,506 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:06<00:00, 15.11it/s, loss=0.7896, auc=0.9598, ap=0.9560, best_auc=0.9624, lr=0.000854]
# 2025-08-07 10:20:18,682 - INFO - Training completed. Best validation AUC: 0.9624
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9552 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9489
#    - acc: 0.8861
#    - pos_acc: 0.9409
#    - neg_acc: 0.8313
#    - p@r0.1: 0.9915
#    - p@r0.3: 0.9832
#    - p@r0.5: 0.9766
#    - p@r0.7: 0.9359
#    - p@r0.9: 0.8855
#
# 🔮 Generating advanced predictions...
# 2025-08-07 10:20:18,697 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 10:20:18,702 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4898.62it/s]
# 2025-08-07 10:20:34,407 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 10:20:38,063 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 789)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9552
#    - Test AP: 0.9489
#    - Precision@Recall=0.9: 0.8855
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_102034_seed789.txt
#
# 🎲 RUN #5/5 - SEED: 999
# ============================================================
# 🎲 RUN - SEED: 999
# ============================================================
#
# 🖥️ Device: cuda
#
# 📊 Loading graph: knowledge_graph_outputs/physics_knowledge_graph_v2_20250807_101448.pt
#
# 📈 Graph Statistics:
#    - Total nodes: 639
#    - Total edges: 5903
#    - Node features: 12
#    - Edge attributes: torch.Size([11806, 3])
#    - Equations: 400
#    - Concepts: 239
#    This will exploit the 4557 equation bridges!
#
# 🔄 Data Split:
#    - Train edges: 4668
#    - Val edges: 583
#    - Test edges: 584
#
# 🧠 SUPER GNN Architecture:
#    - Type: Multi-Head GAT with Edge Weights
#    - Attention Heads: 4 → 2 → 1
#    - Hidden Dimensions: 64 → 32 → 16
#    - Total Parameters: 52,065
#    - Edge Attribute Dimensions: 3
#    - Uses Physics-Aware Decoder: Yes
# 2025-08-07 10:20:38,100 - INFO - Model on device: cuda
# 2025-08-07 10:20:38,100 - INFO - Total parameters: 52,065
#
# 🚀 Starting SUPER GNN training...
#    This will exploit the 4557 equation bridges!
# 2025-08-07 10:20:38,102 - INFO - Starting Super GNN training for 1000 epochs...
# 2025-08-07 10:20:38,102 - INFO - Using edge attributes: True
# Training Super GNN: 100% 1000/1000 [01:05<00:00, 15.20it/s, loss=0.7930, auc=0.9533, ap=0.9462, best_auc=0.9633, lr=0.000854]
# 2025-08-07 10:21:43,876 - INFO - Training completed. Best validation AUC: 0.9633
#
# 📊 Evaluating on test set...
#
# Test Performance:
#    - auc: 0.9569 (95% CI: 0.0000-0.0000, p=1.0000e+00)
#    - ap: 0.9492
#    - acc: 0.8951
#    - pos_acc: 0.9332
#    - neg_acc: 0.8570
#    - p@r0.1: 0.9915
#    - p@r0.3: 0.9777
#    - p@r0.5: 0.9621
#    - p@r0.7: 0.9479
#    - p@r0.9: 0.8855
#
# 🔮 Generating advanced predictions...
# 2025-08-07 10:21:43,892 - INFO - Generating predictions for all possible new links (focus on equations)...
# 2025-08-07 10:21:43,897 - INFO - Focusing on 400 equation nodes
# Generating predictions:  94% 75400/79800 [00:15<00:00, 4786.74it/s]
# 2025-08-07 10:21:59,960 - INFO - Generated 75400 potential new links.
#
# 📈 Performing deep analysis...
# 2025-08-07 10:22:03,579 - INFO - Results saved to super_gnn_results/
#
# ============================================================
# ✅ RUN COMPLETE! (SEED: 999)
# ============================================================
#
# 📊 FINAL METRICS:
#    - Test AUC: 0.9569
#    - Test AP: 0.9492
#    - Precision@Recall=0.9: 0.8855
#
# 🎯 KEY DISCOVERIES:
#
# 📁 Full report saved to: super_gnn_results/super_report_20250807_102200_seed999.txt
#
# ================================================================================
# 🎉 ALL 5 DETERMINISTIC RUNS COMPLETED!
# ================================================================================
#
# 📊 AGGREGATE METRICS ACROSS SEEDS:
#    - AUC: 0.9548 ± 0.0071 (seeds: [42, 123, 456, 789, 999])
#    - AP:  0.9475 ± 0.0074 (seeds: [42, 123, 456, 789, 999])
#
# 🚀 The Super GNN has revealed the hidden structure of physics!
